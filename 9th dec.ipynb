# %% [markdown]
# <a href="https://colab.research.google.com/github/mangaraiarchana/demo-github/blob/main/9th%20dec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# area of rectangle
L =10
B =3
a = L * B
print(a)
# Out:
# 30

# %%
x = int(input("enter length value "))
y = int(input("enter breadth value "))
a = x * y
print(a)
# Out:
# enter length value 2
# enter breadth value 3
# 6

# %%
print(x)
# Out:
# 2

# %%
print(10 * 'archu ')
# Out:
# archu archu archu archu archu archu archu archu archu archu

# %%
print('mangarai '  + 'archana')
# Out:
# mangarai archana

# %%
print('@ ' + '6')
# Out:
# @ 6

# %%
x = int(input("enter length value "))
y = int(input("enter breadth value "))
a = x * y
print(a)
# Out:
# enter length value 10
# enter breadth value 5
# 50

# %%
name = input("enter a name ")
Age = input("enter age ")
print('my name is' , name, 'and my age is '  + Age )
# Out:
# enter a name archana
# enter age 2
# my name is archana and my age is 2
